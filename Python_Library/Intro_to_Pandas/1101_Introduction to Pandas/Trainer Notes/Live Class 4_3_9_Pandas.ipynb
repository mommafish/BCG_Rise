# %%
import pandas as pd

# %% [markdown]
# # Loading data

# %%
# 1D datatype: Series
# 2D datatype: Dataframe (tabular)

# %%
# Load with default index
df = pd.read_csv('brics.csv')
df.head()
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
# Load and set the first column as index
df = pd.read_csv('brics.csv', index_col=0)
df.head()
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %%
# Return (row, column)
df.shape
# Out:
# (5, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, BR to SA
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     5 non-null      object
#  1   population  5 non-null      int64
#  2   area        5 non-null      int64
#  3   capital     5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 200.0+ bytes

# %%
df
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %% [markdown]
# # Access Values

# %% [markdown]
# **By Columns**

# %%
df['country']
# Out:
# code
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
df.country
# Out:
# code
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
df[ ['country', 'population'] ]
# Out:
#            country  population
# code
# BR          Brazil         200
# RU          Russia         144
# IN           India        1252
# CH           China        1357
# SA    South Africa          55

# %%
df[ ['country'] ]
# Out:
#            country
# code
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa

# %% [markdown]
# **Access by rows and/or columns**

# %%
df
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %%
# Method 1: using loc --> Template is .loc[rows, columns]
df.loc['RU']
# Out:
# country         Russia
# population         144
# area          17098242
# capital         Moscow
# Name: RU, dtype: object

# %%
df.loc['RU', 'area']
# Out:
# 17098242

# %%
# Also method 1 but with slicing
df.loc['RU':'CH', 'country':'area']
# Out:
#      country  population      area
# code
# RU    Russia         144  17098242
# IN     India        1252   3287590
# CH     China        1357   9596961

# %%
# Method 2: using iloc --> Template is .iloc[row indices, column indices]
df.iloc[1]
# Out:
# country         Russia
# population         144
# area          17098242
# capital         Moscow
# Name: RU, dtype: object

# %%
df.iloc[1,2]
# Out:
# 17098242

# %%
# Method 2 but with slicing
df.iloc[1:4,0:3]
# Out:
#      country  population      area
# code
# RU    Russia         144  17098242
# IN     India        1252   3287590
# CH     China        1357   9596961

# %%
df.iloc[:,3]
# Out:
# code
# BR     Brasilia
# RU       Moscow
# IN    New Delhi
# CH      Beijing
# SA     Pretoria
# Name: capital, dtype: object

# %% [markdown]
# **Accessing Rows using boolean indexing (mostly for filtering)**

# %%
df
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %%
df[ [False, True, True, True, False] ]
# Out:
#      country  population      area    capital
# code
# RU    Russia         144  17098242     Moscow
# IN     India        1252   3287590  New Delhi
# CH     China        1357   9596961    Beijing

# %%
df['population'] > 1000
# Out:
# code
# BR    False
# RU    False
# IN     True
# CH     True
# SA    False
# Name: population, dtype: bool

# %%
df[ df['population'] > 1000 ]
# Out:
#      country  population     area    capital
# code
# IN     India        1252  3287590  New Delhi
# CH     China        1357  9596961    Beijing

# %% [markdown]
# # Append Values

# %%
df
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %% [markdown]
# **Add new column**

# %%
# Method 1: align with a list or series
new_column = [True, False, False, False, True]
df['on_america'] = new_column
df
# Out:
#            country  population      area    capital  on_america
# code
# BR          Brazil         200   8515767   Brasilia        True
# RU          Russia         144  17098242     Moscow       False
# IN           India        1252   3287590  New Delhi       False
# CH           China        1357   9596961    Beijing       False
# SA    South Africa          55   1221037   Pretoria        True

# %%
df['new column'] = 100
df
# Out:
#            country  population      area    capital  on_america  new column
# code
# BR          Brazil         200   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
# CH           China        1357   9596961    Beijing       False         100
# SA    South Africa          55   1221037   Pretoria        True         100

# %%
df['pop_density'] = df['population'] / df['area'] * 1000000
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         200   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
# CH           China        1357   9596961    Beijing       False         100
# SA    South Africa          55   1221037   Pretoria        True         100
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680

# %% [markdown]
# **Add new row**

# %%
# Method 1
df.loc['SG'] = ['Singapore', 6, 671, 'Singapore', False, 100, 6/671*1000000]
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         200   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
# CH           China        1357   9596961    Beijing       False         100
# SA    South Africa          55   1221037   Pretoria        True         100
# SG       Singapore           6       671  Singapore       False         100
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794

# %%
# Method 2: using .append
df2 = df.iloc[:3]
df2
# Out:
#      country  population      area    capital  on_america  new column  \
# code
# BR    Brazil         200   8515767   Brasilia        True         100
# RU    Russia         144  17098242     Moscow       False         100
# IN     India        1252   3287590  New Delhi       False         100
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076

# %%
df.append(df2)
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         200   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
# CH           China        1357   9596961    Beijing       False         100
# SA    South Africa          55   1221037   Pretoria        True         100
# SG       Singapore           6       671  Singapore       False         100
# BR          Brazil         200   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794
# BR      23.485847
# RU       8.421918
# IN     380.826076

# %%
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         200   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
# CH           China        1357   9596961    Beijing       False         100
# SA    South Africa          55   1221037   Pretoria        True         100
# SG       Singapore           6       671  Singapore       False         100
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794

# %% [markdown]
# # Change values

# %%
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         200   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
# CH           China        1357   9596961    Beijing       False         100
# SA    South Africa          55   1221037   Pretoria        True         100
# SG       Singapore           6       671  Singapore       False         100
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794

# %%
df.loc['BR','population'] = 211
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         211   8515767   Brasilia        True         100
# RU          Russia         144  17098242     Moscow       False         100
# IN           India        1252   3287590  New Delhi       False         100
# CH           China        1357   9596961    Beijing       False         100
# SA    South Africa          55   1221037   Pretoria        True         100
# SG       Singapore           6       671  Singapore       False         100
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794

# %%
df['new column'] = 200
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         211   8515767   Brasilia        True         200
# RU          Russia         144  17098242     Moscow       False         200
# IN           India        1252   3287590  New Delhi       False         200
# CH           China        1357   9596961    Beijing       False         200
# SA    South Africa          55   1221037   Pretoria        True         200
# SG       Singapore           6       671  Singapore       False         200
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794

# %% [markdown]
# # Delete

# %%
# Put cursor inside a function, then press shift+tab --> to read documentation

# %%
# delete row
df.drop('SA', axis=0)
# Out:
#         country  population      area    capital  on_america  new column  \
# code
# BR       Brazil         211   8515767   Brasilia        True         200
# RU       Russia         144  17098242     Moscow       False         200
# IN        India        1252   3287590  New Delhi       False         200
# CH        China        1357   9596961    Beijing       False         200
# SG    Singapore           6       671  Singapore       False         200
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SG    8941.877794

# %%
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         211   8515767   Brasilia        True         200
# RU          Russia         144  17098242     Moscow       False         200
# IN           India        1252   3287590  New Delhi       False         200
# CH           China        1357   9596961    Beijing       False         200
# SA    South Africa          55   1221037   Pretoria        True         200
# SG       Singapore           6       671  Singapore       False         200
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794

# %%
# delete column. Can use inplace to change the dataframe, or simply overwrite the variable
new_df = df.drop('population', axis=1)

# %%
df
# Out:
#            country  population      area    capital  on_america  new column  \
# code
# BR          Brazil         211   8515767   Brasilia        True         200
# RU          Russia         144  17098242     Moscow       False         200
# IN           India        1252   3287590  New Delhi       False         200
# CH           China        1357   9596961    Beijing       False         200
# SA    South Africa          55   1221037   Pretoria        True         200
# SG       Singapore           6       671  Singapore       False         200
#
#       pop_density
# code
# BR      23.485847
# RU       8.421918
# IN     380.826076
# CH     141.398928
# SA      45.043680
# SG    8941.877794

# %%
# Save file
new_df.to_csv('new_df.csv', index=False)

# %% [markdown]
# # Rename Columns

# %%
new_df
# Out:
#            country      area    capital  on_america  new column  pop_density
# code
# BR          Brazil   8515767   Brasilia        True         200    23.485847
# RU          Russia  17098242     Moscow       False         200     8.421918
# IN           India   3287590  New Delhi       False         200   380.826076
# CH           China   9596961    Beijing       False         200   141.398928
# SA    South Africa   1221037   Pretoria        True         200    45.043680
# SG       Singapore       671  Singapore       False         200  8941.877794

# %%
# method 1
new_df = new_df.rename( {'country':"COUNTRY"}, axis=1 )

# %%
new_df
# Out:
#            COUNTRY      area    capital  on_america  new column  \
# code
# BR          Brazil   8515767   Brasilia        True         200
# RU          Russia  17098242     Moscow       False         200
# IN           India   3287590  New Delhi       False         200
# CH           China   9596961    Beijing       False         200
# SA    South Africa   1221037   Pretoria        True         200
# SG       Singapore       671  Singapore       False         200
#
#       POPULATION DENSITY
# code
# BR             23.485847
# RU              8.421918
# IN            380.826076
# CH            141.398928
# SA             45.043680
# SG           8941.877794

# %%
# method 2
new_df.columns = list(new_df.columns[:5]) + ['POPULATION DENSITY']

# %%
new_df
# Out:
#            country      area    capital  on_america  new column  \
# code
# BR          Brazil   8515767   Brasilia        True         200
# RU          Russia  17098242     Moscow       False         200
# IN           India   3287590  New Delhi       False         200
# CH           China   9596961    Beijing       False         200
# SA    South Africa   1221037   Pretoria        True         200
# SG       Singapore       671  Singapore       False         200
#
#       POPULATION DENSITY
# code
# BR             23.485847
# RU              8.421918
# IN            380.826076
# CH            141.398928
# SA             45.043680
# SG           8941.877794
