# %% [markdown]
# # Probability
#
# ### fliping of coin
# 1. heads
# 2. tails
#
# 50% chances of getting head or tail . 0.5 or 1/2 ,
# how many possibilties =  2
# out of 2 possibilties we get only 1 , 0.5 or 1/2
#
# possibility of getting head  = number of possibilites meeting my condition / total number of possibilties
# 1/2
#
# ### dice
#
# outcomes 6 , how many(total)  possibilties = 6 ( 1,2,3,4,5,6)
# possibility of getting 1 =   number of possibilites meeting my condition / total number of possibilties = 1/6
# possibility of getting 2 =   number of possibilites meeting my condition / total number of possibilties = 1/6
# possibility of getting 3 =   number of possibilites meeting my condition / total number of possibilties = 1/6
# possibility of getting 4 =   number of possibilites meeting my condition / total number of possibilties = 1/6
# possibility of getting 5 =   number of possibilites meeting my condition / total number of possibilties = 1/6
# possibility of getting 6 =   number of possibilites meeting my condition / total number of possibilties = 1/6
#
# probability of getting 1,3,5(odd numbers) =   number of probabilites meeting my condition / total number of probabilties = 3/6  = 1/2
#
# probability of getting 2,4,6(even  numbers) =   number of probabilites meeting my condition / total number of probabilties = 3/6  = 1/2
#
#
# ### cards
# 1. how many(total)  probabilties =  52 ( sample space ) = all possible outcomes
#     4 sets/suites =. HEARTS, SPADES, DIAMONDS, CLUBS ( sample points)
#     13 members  = A,J,K,Q,2,3,4,5,6,7,8,9,10
#
#
#     CHANCE OF GETTING KING = number of probabilites meeting my condition / total number of probabilties
#                            = 4/52 = 1/13 = 0.076
#
#     after the we take card = for eg of  King is the result is called EVENT
#
#     CHANCE OF GETTING DIAMOND = number of probabilites meeting my condition / total number of probabilties
#                            = 13/52 = 13/52 =  1/4 = 0.25
#
#
#
#      EG1:  KISHHAN RAAJ
#     NOTATION = P(A)  = 3/11
#
#
#     EG2: FLIP COIN  3 times
#     possibility of getting one HEAD , two TAILS
#
#     number of probabilites meeting my condition / total number of probabilties
#
#     SAMPLE SPACE = total number of probabilties = 2^3 = 8 =  (H,H,H), (T,T,T), (H,H,T), (HTH), HTT, THH, THT, TTH
#
#     SAMPLE POINT = number of probabilites meeting my condition = ONE HEAD, TWO TAILS = THT, TTH, HTT = 3
#
#     ANSWER = 3/8
#
#
#     EG3 : 5 faculties( AKISHAN, BUMANG, CFredy, DJOHN, ERYAN )
#     assessor PANEL of 3   has to be created for your assessment ,
#     what is probability  ,Kishan will be in assessment Panel
#
#
#     number of probabilites meeting my condition / total number of probabilties
#
#     sample space = total number of probabilties
#
#     sample point. = number of probabilites meeting my condition
#
#
#
#     total number of probabilties = 10
#
#     AKISHAN, BUMANG, CFREDY
#     AKISHAN, BUMANG, DJOHN
#     AKISHAN, BUMANG, ERYAN
#     AKISHAN, CFREDY, DJOHN
#     AKISHAN, CFREDY, ERYAN
#     AKISHAN, DJOHN, ERYAN
#     BUMANG, CFREDY , DJOHN
#     BUMANG, CFREDY ,ERYAN
#     BUMANG, DJOHN, ERYAN
#     CFREDY , DJOHN, ERYAN
#
#
#     number of probabilites meeting my condition FOR KISHAN =   6
#
#     AKISHAN, BUMANG, CFREDY
#     AKISHAN, BUMANG, DJOHN
#     AKISHAN, BUMANG, ERYAN
#     AKISHAN, CFREDY, DJOHN
#     AKISHAN, CFREDY, ERYAN
#     AKISHAN, DJOHN, ERYAN
#
#      = 6/10 = 3/5 = 0.6 = 60% CHANCES Kishan is the assessor
#
#
#
#
#
#
# one  covers
#
#  2 black handphones
#  2 green sanitisers
#  2 red  sanitisers
#
# p(red sanitiser)  = 2/6  =1/3
# p(black handphone)  = 2/6  =1/3
#
#
# two   covers
#
# brown cover
#
#
#  2 black handphones
#  5 green sanitisers
#  6 red  sanitisers  =
#
#
#
#  blue cover
#
#  1 black handphones
#  5 green sanitisers
#  4 red  sanitisers
#
#
#  how many events  = 2( picking up cover , picking up the item inside the cover)
#
# p(picking up cover )  p(red  sanitisers)

# %%
cards = 52 # total number of probabilties 
diamonds  =13 # number of probabilites meeting my conditio

#number of probabilites meeting my condition / total number of probabilties

diamond_probability  = diamonds / cards 

print("Diamonds proabil;ity ", diamond_probability)
# Out:
# Diamonds proabil;ity  0.25

# %%
---1. 12% of men covid19 +VE  at some point 
---2. man cough/fever/cold symptoms has 95% chances get covid19 +ve 
---3. man without covid19 symtpoms ,no cough, nofever, 6% chances  c19+ve ( false ) 



what is chance / probability that man has covid given that result is +VE 

P(C) = 12%
P(+/C) = 0.95
P(+/NC) = 0.06

P(C/+) = ?


P(C/+) = P(A|B)  ## probabilitof a given b is true, probability of having covid given the result is true
P(+/C) =  P(B|A) ### Probability fo B given A is true , proability of + given they all covid 
P(C) = P(A)
P(+) = P(B) =?


P(A|B) =   P(B|A) * P(A) / P(B)


calculate P(+) or P(B) =     P(C and "+") + P(NC and "+" )
                       =      12*0.95 + 88*0.06
                       =       11.4 + 5.28
                       =       16.68
            
            
            
P(A|B) =   p(B|A) * P(A) / P(B)

      = 0.95 * 12 / 16.68 
      = 11.4/16.68 
      = 0.6834

# %%
P(A\mid B)=\frac {P(B\mid A) \cdot P(A)}{P(B)}
A, B	=	events
P(A|B)	=	probability of A given B is true
P(B|A)	=	probability of B given A is true
P(A), P(B)	=	the independent probabilities of A and B

# %% [markdown]
# ## Binomial Variables and Distributions
#
#
#
# Table s
# flip coin two times , count number of head ( suces)
# columns which stores the number of heads is binomial variable
#
#
# tabel is called binomial distribution
# binominal variable Column1( number of heads ) Column( Probability)
#
# 0                              25%
# 1                              50%
# 2                              25%
#
#
#
#
#
# B  = Binary
# I =  Indenpendent flip
# N = nUmber of flips is fixed at the begining
# S = Success of each flip
#
#
# binomial distribution
#
# mean
# variance
# SD

# %%
#B  = Binary 
#I =  Indenpendent flip 
#N = nUmber of flips is fixed at the begining 
#S = Success of each flip 

import numpy as np
n = 10
p =0.3
k =  np.arange(0,21)

# %matplotlib inline
from scipy.stats import binom
mean,var =  binom.stats(n,p)

#binomm = binom.pmf(k,n,p)
print(mean,var)
# Out:
# 3.0 2.0999999999999996

# %%
binomm = binom.pmf(k,n,p)
print(binomm)
# Out:
# [2.82475249e-02 1.21060821e-01 2.33474440e-01 2.66827932e-01
#  2.00120949e-01 1.02919345e-01 3.67569090e-02 9.00169200e-03
#  1.44670050e-03 1.37781000e-04 5.90490000e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00]

# %%
import matplotlib.pyplot as plt 
plt.bar(k,binomm)
plt.show()
